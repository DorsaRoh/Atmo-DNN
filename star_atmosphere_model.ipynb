# %%
import os
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import seaborn as sns

df = pd.read_csv('Stellar Data/FDL_data.csv')
df.head()
# Out:
#    Stellar Type  Stellar Temperature  Stellar Radius   Distance  \
# 0           NaN                  NaN             NaN        NaN
# 1           5.0          3865.881545        0.611696   8.641153
# 2           3.0          6021.794551        1.867646  14.332858
# 3           5.0          4942.461589        0.817759  13.639490
# 4           4.0          5765.256871        1.171319   1.380902
#
#    Semi-Major Axis  Planet Radius  Planet Density  Planet Surface Pressure  \
# 0              NaN            NaN             NaN                      NaN
# 1         0.236862    5547.156365          5.2366                 3.132822
# 2         1.715127    4784.145073          4.9958                 4.638380
# 3         0.832709    7876.184048          6.2445                 0.778681
# 4         1.608417   10057.424776          7.5001                 0.164969
#
#       kappa    gamma1  ...  CH4 abundance  N2O abundance  CO abundance  \
# ...

# %% [markdown]
# Data Cleaning and Preprocessing
#
# Keep all relevant data for stars, remove planetary data

# %%
# size of dataset

dataset_size = len(df)
dataset_size # dataset size


# Load and preprocess the data
df.dropna(inplace=True) # drop all rows with NaN values
df = df.drop(['Planet Radius', 'Planet Density', 'Planet Surface Pressure'], axis=1)

X = df.drop(['H20 abundance', 'CO2 abundance', 'O2 abundance', 'N2 abundance', 'CH4 abundance', 'N2O abundance', 'CO abundance', 'O3 abundance', 'SO2 abundance', 'NH3 abundance', 'C2H6 abundance', 'NO2 abundance'], axis=1)
Y = df[['H20 abundance', 'CO2 abundance', 'O2 abundance', 'N2 abundance', 'CH4 abundance', 'N2O abundance', 'CO abundance', 'O3 abundance', 'SO2 abundance', 'NH3 abundance', 'C2H6 abundance', 'NO2 abundance']]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# save cleaned data for planet model to new csv file

df.to_csv('Stellar Data/cleaned_data.csv', index=False)
df = pd.read_csv('Stellar Data/cleaned_data.csv')
df.head()
# Out:
#    Stellar Type  Stellar Temperature  Stellar Radius   Distance  \
# 0           5.0          3865.881545        0.611696   8.641153
# 1           3.0          6021.794551        1.867646  14.332858
# 2           5.0          4942.461589        0.817759  13.639490
# 3           4.0          5765.256871        1.171319   1.380902
# 4           4.0          5865.911857        1.106548  13.184614
#
#    Semi-Major Axis     kappa    gamma1    gamma2     alpha      beta  ...  \
# 0         0.236862 -2.729805  0.674501 -0.504562  0.530268  0.946155  ...
# 1         1.715127 -2.745324  0.735622 -0.286948  0.641666  0.756138  ...
# 2         0.832709 -2.585833  1.015678 -0.353109  0.624557  0.914404  ...
# 3         1.608417 -2.030302 -1.412910 -0.808585  0.337483  0.933829  ...
# 4         1.843825 -2.788137  0.897797 -1.359141  0.131381  0.840673  ...
#
#    CH4 abundance  N2O abundance  CO abundance  O3 abundance  SO2 abundance  \
# ...

# %% [markdown]
# Data Splitting

# %%
# convert CSV to a numpy array
data = np.array(df)
m, n = data.shape

# extract the column headers as a numpy array and reshape it
title_row = np.array(df.columns).reshape(1, n)

# shuffle the array
np.random.seed(42)
indices = np.arange(data.shape[0])
np.random.shuffle(indices)

data_shuffled = data[indices]

# split the array
train_idx = int(0.7 * data.shape[0])
test_idx = int(0.9 * data.shape[0])

train = np.vstack([title_row, data_shuffled[:train_idx]])
test = np.vstack([title_row, data_shuffled[train_idx:test_idx]])
validate = np.vstack([title_row, data_shuffled[test_idx:]])

# Ensure directories exist, if not, create them
os.makedirs('Stellar Data/train/', exist_ok=True)
os.makedirs('Stellar Data/test/', exist_ok=True)
os.makedirs('Stellar Data/validate/', exist_ok=True)

# Save numpy arrays to CSV. Add fmt='%s' to handle both strings (headers) and numbers.
np.savetxt('Stellar Data/train/train_data.csv', train, delimiter=',', fmt='%s')
np.savetxt('Stellar Data/test/test_data.csv', test, delimiter=',', fmt='%s')
np.savetxt('Stellar Data/validate/validation_data.csv', validate, delimiter=',', fmt='%s')

# %% [markdown]
# Data Visualization

# %%
# heatmap

# ensure the data in df is of numeric type (if not, the heatmap won't work)
df = df.apply(pd.to_numeric, errors='coerce')

# create heatmap
plt.figure(figsize=(15, 8))
sns.heatmap(df, annot=True, cmap='viridis', cbar_kws={'label': 'Value'})
plt.title("Heatmap of Stellar Data")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# histogram

plt.figure(figsize=(10,6))
sns.histplot(df['Stellar Temperature'], bins=30, kde=True, color="skyblue")
plt.title('Distribution of Stellar Surface Temperature')
plt.xlabel('Stellar Temperature')
plt.ylabel('Number of Stars')
plt.show()

# %%
# scatter plot

# ensure data is numeric
df = df.apply(pd.to_numeric, errors='coerce')

# create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Stellar Radius'], df['Stellar Temperature'], c=df['Stellar Temperature'], cmap='viridis', edgecolors='k')
plt.colorbar(label='Stellar Surface Temperature')
plt.title('Scatter Plot of Stellar Radius vs. Stellar Temperature')
plt.xlabel('Stellar Radius')
plt.ylabel('Stellar Temperature')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Model Architecture (deep learning model from scratch)

# %%
def initialize_weights(input_dim, hidden_layers, output_dim):
    np.random.seed(42)
    layers = [input_dim] + hidden_layers + [output_dim]
    weights = []
    biases = []
    gamma = []
    beta = []
    for i in range(len(layers)-1):
        weights.append(np.random.randn(layers[i], layers[i+1]) * 0.01)
        biases.append(np.zeros(layers[i+1]))
        gamma.append(np.ones(layers[i+1]))
        beta.append(np.zeros(layers[i+1]))
    return weights, biases, gamma, beta

def relu(Z):
    return np.maximum(0, Z)

def relu_backward(dA, Z):
    dZ = np.array(dA, copy=True)
    dZ[Z <= 0] = 0
    return dZ

def batchnorm_forward(Z, gamma, beta):
    mu = np.mean(Z, axis=0)
    var = np.var(Z, axis=0)
    Z_normalized = (Z - mu) / np.sqrt(var + 1e-8)
    out = gamma * Z_normalized + beta
    cache = (Z, mu, var, gamma, beta)
    return out, cache


def forward_pass(X, weights, biases, gamma=None, beta=None, dropout_ratio=0.5):
    A = X
    cache = {"A0": X}
    drop_cache = {}
    for i in range(len(weights)):
        Z = np.dot(A, weights[i]) + biases[i]
        if i != len(weights) - 1:
            if gamma and beta:  # Check if gamma and beta are provided
                Z, bn_cache = batchnorm_forward(Z, gamma[i], beta[i])
                cache["bn" + str(i+1)] = bn_cache
            A = relu(Z)
            # Dropout
            D = np.random.rand(*A.shape) < dropout_ratio
            A *= D
            A /= dropout_ratio
            drop_cache["D" + str(i+1)] = D
        else:
            A = Z
        cache["Z" + str(i + 1)] = Z
        cache["A" + str(i + 1)] = A
    return A, cache, drop_cache


def update_parameters(weights, biases, grads, learning_rate):
    for i, W in enumerate(weights):
        W -= learning_rate * grads["dW" + str(i + 1)]
        biases[i] -= learning_rate * grads["db" + str(i + 1)]

def compute_cost_with_regularization(Y_hat, Y, weights, lambd):
    m = Y.shape[0]
    L2_regularization_cost = sum(np.sum(np.square(w)) for w in weights)
    return MSE(Y_hat, Y) + (lambd / (2 * m)) * L2_regularization_cost

def backward_pass_with_regularization(Y, cache, weights, lambd):
    m = Y.shape[0]
    dA = cache["A" + str(len(weights))] - Y
    grads = {}
    for i in range(len(weights), 0, -1):
        dZ = relu_backward(dA, cache["Z" + str(i)])
        grads["dW" + str(i)] = (1/m) * np.dot(cache["A" + str(i - 1)].T, dZ) + (lambd/m) * weights[i-1]
        grads["db" + str(i)] = (1/m) * np.sum(dZ, axis=0)
        dA = np.dot(dZ, weights[i-1].T)
    return grads

def get_learning_rate(base_lr, iteration, decay_rate, decay_step):
    return base_lr * (1 / (1 + decay_rate * (iteration/decay_step)))

def train(X, Y, base_learning_rate, decay_rate, num_iterations, hidden_layers, lambd, dropout_ratio=0.5):
    input_dim = X.shape[1]
    output_dim = 1 if len(Y.shape) == 1 else Y.shape[1]
    weights, biases, gamma, beta = initialize_weights(input_dim, hidden_layers, output_dim)
    for i in range(num_iterations):
        learning_rate = get_learning_rate(base_learning_rate, i, decay_rate, 100)
        Y_hat, cache, drop_cache = forward_pass(X, weights, biases, gamma, beta, dropout_ratio)
        cost = compute_cost_with_regularization(Y_hat, Y, weights, lambd)
        grads = backward_pass_with_regularization(Y, cache, weights, lambd)
        update_parameters(weights, biases, grads, learning_rate)
        if i % 100 == 0:
            print(f"Iteration {i}, Cost: {cost}")
    return weights, biases

def MSE(Y_pred, Y_true):
    return np.mean(np.square(Y_pred - Y_true))

def predict(X, weights, biases):
    Y_hat, _, _ = forward_pass(X, weights, biases, dropout_ratio=1)  # Skip gamma and beta here
    return Y_hat

# Call the train function
lambd = 0.7
base_learning_rate = 0.01
decay_rate = 0.01
dropout_ratio = 0.5

# Assuming X_train and Y_train are defined
weights, biases = train(X_train, Y_train, base_learning_rate, decay_rate, num_iterations=1000, hidden_layers=[128, 64, 32], lambd=lambd, dropout_ratio=dropout_ratio)

# Assuming X_test and Y_test are defined
Y_pred = predict(X_test, weights, biases)
print(f"Test MSE: {MSE(Y_pred, Y_test)}")
# Out:
# Iteration 0, Cost: 40.504799156316324
# Iteration 100, Cost: 30.798887668726792
# Iteration 200, Cost: 33.318775684836034
# Iteration 300, Cost: 32.685154588758195
# Iteration 400, Cost: 32.08856059162679
# Iteration 500, Cost: 30.533145069545007
# Iteration 600, Cost: 34.12281633856343
# Iteration 700, Cost: 35.207335978693315
# Iteration 800, Cost: 32.20158547003825
# Iteration 900, Cost: 32.55808872385116
# Test MSE: 0.011095532867417116

# %% [markdown]
# Model Accuracy

# %%
def regression_accuracy(Y_pred, Y_true, threshold=0.3):
    """Calculate 'accuracy' for regression.
    
    Args:
    - Y_pred (np.array): Predicted values.
    - Y_true (np.array): True values.
    - threshold (float): The acceptable range for a prediction to be considered 'correct'.
    
    Returns:
    - accuracy (float): Pseudo accuracy for the regression task.
    """
    correct_predictions = np.abs(Y_pred - Y_true) <= threshold
    accuracy = np.mean(correct_predictions) * 100  # in percentage
    return accuracy

# Assuming Y_pred and Y_test are your prediction and ground truth respectively
accuracy = regression_accuracy(Y_pred, Y_test.values)
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Accuracy: 96.43%

# %% [markdown]
# Model Prediction Visualization

# %%
def plot_residuals(Y_true, Y_pred):
    residuals = Y_true - Y_pred
    plt.figure(figsize=(10, 6))
    
    plt.hist(residuals, bins=50, alpha=0.7)
    
    plt.xlabel('Residual Value')
    plt.ylabel('Frequency')
    plt.title('Distribution of Residuals')
    plt.grid(True)
    plt.show()

plot_residuals(Y_test, Y_pred)
