# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
# load dataset
df = pd.read_csv('planetary_data.csv')
df = df.dropna()

# output (targets)
output_columns = ['H20 abundance', 'CO2 abundance',
       'O2 abundance', 'N2 abundance', 'CH4 abundance', 'N2O abundance',
       'CO abundance', 'O3 abundance', 'SO2 abundance', 'NH3 abundance',
       'C2H6 abundance', 'NO2 abundance']

# inputs
features = df.drop(columns=output_columns)
print(features.columns)
# Out:
# Index(['Semi-Major Axis', 'Planet Radius', 'Planet Density',
#        'Planet Surface Pressure', 'kappa', 'gamma1', 'gamma2', 'alpha', 'beta',
#        'Planet Surface Temperature', 'Avg Mol Weight', 'Mean Surface Albedo'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

# scale each feature between (0,1)
scaler = MinMaxScaler()
features_scaled = pd.DataFrame(scaler.fit_transform(features),columns=features.columns)
features_scaled
# Out:
#      Semi-Major Axis  Planet Radius  Planet Density  Planet Surface Pressure  \
# 0           0.775757       0.542406        0.839183                 0.827523
# 1           0.786523       0.464994        0.837744                 0.836521
# 2           0.780096       0.778700        0.845207                 0.813453
# 3           0.785746       1.000000        0.852710                 0.809785
# 4           0.787460       0.628938        0.840148                 0.811931
# ..               ...            ...             ...                      ...
# 570         0.785746       1.000000        0.852710                 0.809785
# 571         0.787460       0.628938        0.840148                 0.811931
# 572         0.796914       0.814048        0.846500                 0.843600
# 573         0.809545       0.013633        1.000000                 1.000000
# 574         0.000000       0.000000        0.000000                 0.000000
#
# ...

# %% [markdown]
# Splitting the data into training sets and testing/validation sets!

# %%
from sklearn.model_selection import train_test_split

# 40% of data for testing, 60% for training
X_train, X_test = train_test_split(features_scaled, test_size=0.4, random_state=42)
